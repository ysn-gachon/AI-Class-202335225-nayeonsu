# %% [markdown]
# <a href="https://colab.research.google.com/github/ysn-gachon/AI-Class-202335225-nayeonsu/blob/main/Week2/LR4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'

df = pd.read_csv(path)

df

df2=df.drop('label',axis=1)
df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
y=df2['worst compactness']
y.value_counts()
y
# Out:
# 0      0.66560
# 1      0.18660
# 2      0.42450
# 3      0.86630
# 4      0.20500
#         ...
# 564    0.21130
# 565    0.19220
# 566    0.30940
# 567    0.86810
# 568    0.06444
# Name: worst compactness, Length: 569, dtype: float64

# %%
X=df2.drop('worst compactness',axis=1)
X.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  fractal dimension error  worst radius  worst texture  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))  # -> 이걸 이해해보자

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.0005204237064859748
# 평균제곱근오차 0.0005204237064859748
# 평균제곱근오차 0.0005204237064859746

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

model = DecisionTreeRegressor()
model.fit(X_train, y_train)
dt_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(dt_preds, y_test))  # -> 이걸 이해해보자

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(dt_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(dt_preds, y_test))
# Out:
# 평균제곱근오차 0.005831423345614034
# 평균제곱근오차 0.005831423345614034
# 평균제곱근오차 0.0058314233456140336

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

model = MLPRegressor()
model.fit(X_train, y_train)
mp_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(mp_preds, y_test))  # -> 이걸 이해해보자

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(mp_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(mp_preds, y_test))
# Out:
# 평균제곱근오차 1.7431026790756128
# 평균제곱근오차 1.7431026790756128
# 평균제곱근오차 1.7431026790756132
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model = RandomForestRegressor()
model.fit(X_train, y_train)
rf_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(rf_preds, y_test))  # -> 이걸 이해해보자

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(rf_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(rf_preds, y_test))
# Out:
# 평균제곱근오차 0.002296944093511839
# 평균제곱근오차 0.002296944093511839
# 평균제곱근오차 0.002296944093511839

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

model = SVR()
model.fit(X_train, y_train)
sv_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(sv_preds, y_test))  # -> 이걸 이해해보자

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(sv_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(sv_preds, y_test))
# Out:
# 평균제곱근오차 0.021142921244670695
# 평균제곱근오차 0.021142921244670695
# 평균제곱근오차 0.021142921244670692
